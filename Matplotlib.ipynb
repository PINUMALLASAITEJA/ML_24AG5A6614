# %% [markdown]
# <a href="https://colab.research.google.com/github/PINUMALLASAITEJA/ML_24AG5A6614/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introduction to Matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Plotting x and y points

# %%
x = np.array([1,8])
y = np.array([2,10])
plt.plot(x,y)
plt.show()

# %% [markdown]
# Add labels and title

# %%
x = ([1,2,3,4,5])
y = ([1,4,9,14,19])
plt.plot(x,y)
plt.figure(figsize=(8,9))
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line-Chart')
plt.legend(['my data series'])
plt.grid(True)
plt.show()

# %% [markdown]
# Bar Chart

# %%
categories = ['A','B','C','D','E']
values = [5,3,2,4,6]
plt.figure(figsize=(5,6))
plt.bar(categories,values,color='red')
plt.xlabel('categories')
plt.ylabel('values')
plt.title('Bar Chart')
plt.show()

# %% [markdown]
# Histogram

# %%
data = [12, 15, 13, 17, 16, 16, 19, 12, 14, 16, 14, 17, 18, 18, 15, 14]
plt.hist(data,bins=16,edgecolor='black',color='blue')

plt.xlabel('Value')
plt.ylabel('frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# Scatter plot

# %%
x = [1,2,3,4,5]
y = [4,5,6,7,8]
plt.scatter(x,y,color='red')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# Pie chart

# %%
labels = (['A','B','C','D','E'])
size = [25,20,5,10,40]
plt.pie(size,labels = labels,autopct='%1.1f%%',startangle=90)
plt.title('Pie Chart')
plt.axis('equal')
plt.show()

# %% [markdown]
# Box plot

# %%
data = [7, 8, 5, 6, 7, 9, 12, 5, 7, 8, 6]
plt.boxplot(data)
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()

# %% [markdown]
# Heatmap

# %%
data = np.random.rand(10,10)
plt.imshow(data,cmap='viridis',interpolation ='nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()
